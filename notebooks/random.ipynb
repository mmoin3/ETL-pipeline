# %%
import os, sys
from pathlib import Path
sys.path.append(str(Path("..").resolve()))
import pandas as pd
from config import RAW_DATA_DIR, ROOT_DIR
from src.parsers.inav_bskt import INAVBskt

# %%
nav_file = RAW_DATA_DIR + "/Harvest_INAVBSKT_ALL.20260218.csv"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 5
#       3 df = INAVBskt(nav_file).extract()[0]
#       4 df = pd.MultiIndex.from_frame(df)
# ----> 5 print(df.head())
#
# AttributeError: 'MultiIndex' object has no attribute 'head'

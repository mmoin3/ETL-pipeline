# %%
import os, sys
from pathlib import Path
sys.path.append(str(Path("..").resolve()))
import pandas as pd
from config import RAW_DATA_DIR, ROOT_DIR
from src.parsers.inav_bskt import INAVBskt

# %%
nav_file = RAW_DATA_DIR + "\Harvest_INAVBSKT_ALL.20260218.csv"

df = pd.read_csv(nav_file)
print(df.head())
# Out:
#   Cell In[3], line 1
#     nav_file = "/C:\Users\mmoin\PYTHON PROJECTS\ETL-pipeline\data\0_raw data\Harvest_INAVBSKT_ALL.20260218.csv"
#                ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 3-4: truncated \UXXXXXXXX escape

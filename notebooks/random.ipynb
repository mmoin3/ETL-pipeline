# %%
import pandas as pd
import sys
from pathlib import Path
sys.path.append(str(Path("..").resolve()))
from src.services import bloomberg_client
from src.parsers import extract_ucf

# %%
ucf_file = Path(r"C:\Users\mmoin\PYTHON PROJECTS\DataWareHouse\data\0_raw data\Harvest_UCF.20260409.CSV")
    df = extract_ucf(ucf_file)
    print(df.columns)
    print(df.head(15))

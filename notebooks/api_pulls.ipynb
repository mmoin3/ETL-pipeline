# %%
import requests
import json
import pandas as pd
import os, sys
from pathlib import Path
sys.path.append(str(Path("..").resolve()))
from config import FIGI_API_KEY

# %%
myurl = r"https://api.openfigi.com/v3/mapping/values/marketSecDes"
myreq = [{"idType":"TICKER", "idValue":"AAPL","exchCode":"US"}]
headers = {"Content-Type": "application/json",
           "X-OPENFIGI-APIKEY": FIGI_API_KEY}

response = requests.post(myurl, data=json.dumps(myreq), headers=headers)

# %%
print(response)
# Out:
# <Response [404]>
